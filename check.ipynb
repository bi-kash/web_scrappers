# %%
import pandas as pd

# %%
df = pd.read_csv('data/2018-11-06_sample_ballots.csv')

# %%
# print in pretty format. SO that i can see json clearlty

import json
print(json.dumps(df.sample(10).to_dict(orient='records'), indent=2))
# Out:
# [
#   {
#     "pdf_file": "HOKE-20181106-Style007-ROCKFISH-GEN.pdf",
#     "pdf_url": "https://s3.amazonaws.com/dl.ncsbe.gov/data/SampleBallots/2018-11-06/HOKE-20181106-Style007-ROCKFISH-GEN.pdf",
#     "office1": "NC Superior Court Judge District 19D Seat 1",
#     "candidate1_1": "Michael (Mike) Stone",
#     "candidate1_2": "Gregory B. Thompson",
#     "candidate1_3": NaN,
#     "office2": "NC District Court Judge District 19D Seat 1",
#     "candidate2_1": "Warren McSweeney",
#     "candidate2_2": NaN,
#     "office3": "NC District Court Judge District 19D Seat 2",
#     "candidate3_1": "Brian Godfrey",
#     "candidate3_2": "Regina M. Joe",
#     "candidate3_3": "Steve Bibey",
#     "office4": NaN,
#     "candidate4_1": NaN,
#     "office5": NaN,
#     "candidate5_1": NaN,
#     "office6": NaN,
#     "candidate6_1": NaN,
#     "candidate6_2": NaN,
#     "office7": NaN,
#     "candidate7_1": NaN,
#     "office8": NaN,
#     "candidate8_1": NaN
#   },
#   {
# ...

# %%
df[df['pdf_file']== '0GPEND01.pdf']
